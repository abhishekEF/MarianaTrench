# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/avinchure/Desktop/corescore/data/01_raw/WindPower.csv", encoding='latin-1')
data
# Out:
#        case_id    faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# 0      3072695        NaN               NaN      5143.0  52161.0      CA
# 1      3072704        NaN               NaN      5146.0  52161.0      CA
# 2      3072661        NaN               NaN      5149.0  52161.0      CA
# 3      3063269  19-028130  2016-WTE-5934-OE         NaN      NaN      IA
# 4      3063321  19-028135  2014-WTE-4087-OE         NaN      NaN      IA
# ...        ...        ...               ...         ...      ...     ...
# 71661  3053232  36-120351  2015-WTE-5788-OE         NaN      NaN      NY
# 71662  3101958  48-171972  2020-WTW-2021-OE         NaN      NaN      TX
# 71663  3040944  48-024978   2011-WTW-352-OE     41364.0      NaN      TX
# 71664  3055918  08-072237  2015-WTW-9995-OE         NaN      NaN      CO
# 71665  3055917  08-072245  2015-WTW-9994-OE         NaN      NaN      CO
#
#              t_county  t_fips                   p_name  p_year  ...     t_rsa  \
# ...

# %%
state_filter = data["t_state"] == "MN"
data = data.loc[state_filter]
Wind = data[["t_state", "t_county", "p_name", "p_year", "p_tnum", "p_cap", "t_cap", "retrofit", "t_conf_atr", "t_conf_loc", "xlong", "ylat"]]
Wind
# Out:
#       t_state          t_county                       p_name  p_year  p_tnum  \
# 165        MN     Meeker County  Adams Wind Generations, LLC  2011.0      12
# 166        MN     Meeker County  Adams Wind Generations, LLC  2011.0      12
# 167        MN     Meeker County  Adams Wind Generations, LLC  2011.0      12
# 168        MN     Meeker County  Adams Wind Generations, LLC  2011.0      12
# 169        MN     Meeker County  Adams Wind Generations, LLC  2011.0      12
# ...       ...               ...                          ...     ...     ...
# 70046      MN  Pipestone County     unknown Pipestone County  2018.0       6
# 70047      MN  Pipestone County     unknown Pipestone County  2018.0       6
# 70075      MN   Renville County      unknown Renville County  2020.0       1
# 70368      MN  Sherburne County     unknown Sherburne County  2020.0       1
# 71409      MN   Watonwan County      unknown Watonwan County  2013.0       1
#
# ...

# %%
data
# Out:
#        case_id faa_ors faa_asn  usgs_pr_id  eia_id t_state t_county  t_fips  \
# 0          NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 1          NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 2          NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 3          NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 4          NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# ...        ...     ...     ...         ...     ...     ...      ...     ...
# 71661      NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 71662      NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 71663      NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 71664      NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
# 71665      NaN     NaN     NaN         NaN     NaN     NaN      NaN     NaN
#
# ...
